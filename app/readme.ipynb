# %% [markdown]
# We will be working on predicting the win_probability of a congressional candidate depending upon the forecast data. We will consider all the features that we might think be influential for the target value.

# %%
import pandas as pd

# %%
df = pd.read_csv("data/house_district_forecast.csv")

# %% [markdown]
# # Get to know the data
#
# We are going to see how our data looks

# %%
df.head()
# Out:
#   forecastdate state  district  special           candidate party  incumbent  \
# 0   2018-08-01    AK         1      NaN           Don Young     R       True
# 1   2018-08-01    AK         1      NaN     Alyse S. Galvin     D      False
# 2   2018-08-01    AK         1      NaN              Others   NaN      False
# 3   2018-08-01    AL         1      NaN       Bradley Byrne     R       True
# 4   2018-08-01    AL         1      NaN  Robert Kennedy Jr.     D      False
#
#      model  win_probability  voteshare  p10_voteshare  p90_voteshare
# 0  classic           0.7185      49.35          43.04          55.59
# 1  classic           0.2815      44.11          37.77          50.39
# 2  classic           0.0000       6.54           2.60          11.17
# 3  classic           0.9993      64.90          59.71          69.94
# 4  classic           0.0007      35.10          30.06          40.29

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302859 entries, 0 to 302858
# Data columns (total 12 columns):
# forecastdate       302859 non-null object
# state              302859 non-null object
# district           302859 non-null int64
# special            0 non-null float64
# candidate          302859 non-null object
# party              283602 non-null object
# incumbent          302859 non-null bool
# model              302859 non-null object
# win_probability    302859 non-null float64
# voteshare          302859 non-null float64
# p10_voteshare      302859 non-null float64
# p90_voteshare      302859 non-null float64
# dtypes: bool(1), float64(5), int64(1), object(5)
# memory usage: 25.7+ MB

# %%
df.describe()
# Out:
#             district  special  win_probability      voteshare  p10_voteshare  \
# count  302859.000000      0.0    302859.000000  302859.000000  302859.000000
# mean        9.641635      NaN         0.421354      42.163495      37.157514
# std        10.260220      NaN         0.453051      24.946290      24.353250
# min         1.000000      NaN         0.000000       0.000000      -4.650000
# 25%         3.000000      NaN         0.000100      23.950000      18.100000
# 50%         6.000000      NaN         0.127800      44.430000      39.070000
# 75%        12.000000      NaN         0.992600      60.880000      54.890000
# max        53.000000      NaN         1.000000     100.000000     100.000000
#
#        p90_voteshare
# count  302859.000000
# mean       47.254966
# std        25.456194
# min        -1.220000
# 25%        30.340000
# 50%        49.830000
# 75%        66.720000
# max       100.000000

# %% [markdown]
# lets take a look at the "party" column distribution

# %%
df['party'].value_counts()
# Out:
# D                         129948
# R                         116745
# LIB                        17982
# IND                         3822
# GRE                         2439
# I                           2058
# REF                         1764
# G                           1764
# L                           1188
# US Taxpayers                 882
# CON                          882
# AME                          882
# Working Class                588
# NPA                          588
# IPO                          294
# DPD                          294
# Legal Marijuana Now          294
# WOF                          294
# Reform Party                 294
# Independence Party           294
# Mountain                     294
# Women's Equality Party        12
# Name: party, dtype: int64

# %% [markdown]
# # Get to know your features
#
# We are going to look at how the columns are skewed using histogram. After looking at the individual column data we might want to do feature scaling or feature aggregation.

# %%
import matplotlib.pyplot as plt

# %%
dfplot = df.drop(columns=['special','incumbent'])

# %%
dfplot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302859 entries, 0 to 302858
# Data columns (total 10 columns):
# forecastdate       302859 non-null object
# state              302859 non-null object
# district           302859 non-null int64
# candidate          302859 non-null object
# party              283602 non-null object
# model              302859 non-null object
# win_probability    302859 non-null float64
# voteshare          302859 non-null float64
# p10_voteshare      302859 non-null float64
# p90_voteshare      302859 non-null float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 23.1+ MB

# %%
dfplot.hist(bins=50,figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1170db3828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1170b2cb00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1170ae30b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1170a87630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1170ab0ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1170a62160>]],
#       dtype=object)

# %% [markdown]
# All we got to know is few of them are skewed to left or have outliers. Since the district feature doesnt make sense on its own, we might want to aggregate it with state.

# %%
df["state_district"] = df["state"].map(str)+"_"+df["district"].map(str)

# %%
df["voteshare"].value_counts()/len(df)
# Out:
# 100.00    0.017473
# 3.24      0.005210
# 3.18      0.004160
# 3.31      0.003427
# 3.04      0.003213
# 2.93      0.003120
# 2.87      0.003001
# 3.41      0.003001
# 2.81      0.002496
# 2.80      0.002318
# 3.44      0.002268
# 2.94      0.002199
# 3.49      0.002159
# 3.02      0.002143
# 3.48      0.002140
# 3.22      0.002130
# 3.33      0.002080
# 3.01      0.002060
# 3.98      0.002021
# 3.54      0.002011
# 3.39      0.001975
# 2.83      0.001951
# 2.54      0.001941
# 4.29      0.001866
# 3.36      0.001793
# 3.09      0.001714
# 2.98      0.001654
# 3.69      0.001595
# 2.89      0.001496
# 3.11      0.001407
#             ...
# 88.67     0.000003
# 88.83     0.000003
# 87.53     0.000003
# 91.43     0.000003
# 5.94      0.000003
# 96.20     0.000003
# 8.64      0.000003
# 86.70     0.000003
# 92.81     0.000003
# 87.36     0.000003
# 88.63     0.000003
# 90.94     0.000003
# 87.45     0.000003
# 92.31     0.000003
# 93.88     0.000003
# 94.05     0.000003
# 87.59     0.000003
# 87.41     0.000003
# 95.25     0.000003
# 92.19     0.000003
# 96.08     0.000003
# 96.80     0.000003
# 95.75     0.000003
# 93.65     0.000003
# 12.84     0.000003
# 96.25     0.000003
# 94.36     0.000003
# 91.96     0.000003
# 88.07     0.000003
# 93.81     0.000003
# Name: voteshare, Length: 9138, dtype: float64

# %% [markdown]
# To categorize the data for voteshare we create a new column called votershare. In order to keep the no of categories to low we divide the voteshare by 10. we mainly calculate this to get stratified sampling everytime

# %%
import numpy as np
df["voteshare_cat"] = np.ceil(df["voteshare"]/10)
df["voteshare_cat"].value_counts()/len(df)
# Out:
# 1.0     0.174632
# 5.0     0.153666
# 6.0     0.143740
# 4.0     0.139837
# 7.0     0.136380
# 3.0     0.081203
# 8.0     0.069263
# 2.0     0.045899
# 9.0     0.033431
# 10.0    0.021934
# 0.0     0.000013
# Name: voteshare_cat, dtype: float64

# %% [markdown]
# # spliting the data into tarinaing and test sets
#
# We generally split it with 20 to 80 ratio for test and trainig sets. To keep it startified we use the help of sikit learn.

# %%
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2,random_state=42)
for train_index, test_index in split.split(df,df["voteshare_cat"]):
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]

# %%
for set in (strat_train_set,strat_test_set):
    set.drop(["voteshare_cat"], axis=1, inplace=True)

# %%
data_train = strat_train_set.copy()

# %%
correlation_matrix = data_train.corr()
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242287 entries, 268221 to 137396
# Data columns (total 13 columns):
# forecastdate       242287 non-null object
# state              242287 non-null object
# district           242287 non-null int64
# special            0 non-null float64
# candidate          242287 non-null object
# party              226874 non-null object
# incumbent          242287 non-null bool
# model              242287 non-null object
# win_probability    242287 non-null float64
# voteshare          242287 non-null float64
# p10_voteshare      242287 non-null float64
# p90_voteshare      242287 non-null float64
# state_district     242287 non-null object
# dtypes: bool(1), float64(5), int64(1), object(6)
# memory usage: 24.3+ MB

# %% [markdown]
# # Correlation between features
#
# We use correlation matrix to keep or eliminate feature that the data shows might influence our target value.

# %%
correlation_matrix["win_probability"].sort_values(ascending=False)
# Out:
# win_probability    1.000000
# p10_voteshare      0.867031
# voteshare          0.862565
# p90_voteshare      0.856851
# incumbent          0.837702
# district           0.048895
# special                 NaN
# Name: win_probability, dtype: float64

# %%
from pandas.plotting import scatter_matrix

attributes = ["win_probability","state_district","party","voteshare","p10_voteshare","p90_voteshare"]
scatter_matrix(data_train[attributes],figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f115f100630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f115f7ab2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f115cdb5550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f115f108438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f115f0fe9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f115f677f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f115f6c54e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f115f69da90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f115f69dac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f115f725588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f115f74cb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f115f6fe0b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f115f626630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f115f64bba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f115f5ff160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f115f5a56d8>]],
#       dtype=object)

# %% [markdown]
# we can see a strong correlation between winning probability and voteshare a candidate has in their respective districts

# %%
df.plot(kind="scatter", x="voteshare", y="win_probability",alpha=0.1)
plt.show()

# %% [markdown]
# Since the data has no null values except for "special" column, we are dropping the column. As it is has no correlation with win_probability too.

# %%
data_train.drop("special",axis=1)
# Out:
#        forecastdate state  district            candidate party  incumbent  \
# 268221   2018-10-04    MA         2        Tracy Lovvorn     R      False
# 246253   2018-09-13    CA         6      Doris O. Matsui     D       True
# 206983   2018-08-05    VA         2         Scott Taylor     R       True
# 265335   2018-10-01    NJ         7               Others   NaN      False
# 59872    2018-09-28    CA        43         Omar Navarro     R      False
# 197008   2018-11-02    HI         1              Ed Case     D      False
# 105436   2018-08-05    KY         4            Seth Hall     D      False
# 274300   2018-10-10    IL         4  Jesus "Chuy" Garcia     D      False
# 297629   2018-11-01    VA         5      Leslie Cockburn     D      False
# 194609   2018-10-30    VA         1      Vangie Williams     D      False
# 268783   2018-10-04    VA         2         Scott Taylor     R       True
# 206217   2018-08-05    FL         3  Yvonne Hayes Hinson     D      False
# 62000    2018-09-30    FL         7          Mike Miller     R      False
# 122936   2018-08-22    KS         4    James A. Thompson     D      False
# 177581   2018-10-14    MA         9    Peter D. Tedeschi     R      False
# 144920   2018-09-12    OH         6       Shawna Roberts     D      False
# 98562    2018-11-04    OH         6         Bill Johnson     R       True
# 238601   2018-09-05    NY         7   Nydia M. Velázquez     D       True
# 238151   2018-09-05    FL         5            Al Lawson     D       True
# 2867     2018-08-03    SC         4        Brandon Brown     D      False
# 51054    2018-09-19    NJ         2        Seth Grossman     R      False
# 108001   2018-08-07    TX         9             Al Green     D       True
# 297493   2018-11-01    TN         3    Danielle Mitchell     D      False
# 233618   2018-08-31    SC         6     James E. Clyburn     D       True
# 248192   2018-09-14    VA         6       Jennifer Lewis     D      False
# 222479   2018-08-20    WI         1          Randy Bryce     D      False
# 81268    2018-10-18    TX        31          John Carter     R       True
# 113646   2018-08-13    IN         5      Susan W. Brooks     R       True
# 81431    2018-10-19    CA         8            Paul Cook     R       True
# 208595   2018-08-07    MO         5               Others   NaN      False
# ...             ...   ...       ...                  ...   ...        ...
# 70581    2018-10-08    NC         4         Barbara Howe   LIB      False
# 157877   2018-09-25    IA         2   Christopher Peters     R      False
# 11585    2018-08-12    GA        10            Jody Hice     R       True
# 142921   2018-09-10    PA         6        Greg McCauley     R      False
# 32718    2018-09-01    PA        16           Mike Kelly     R       True
# 189607   2018-10-26    CA        14      Cristina Osmeña     R      False
# 250885   2018-09-17    NE         1      Jessica McClure     D      False
# 287294   2018-10-22    TX        31          John Carter     R       True
# 265285   2018-10-01    NC         7         David Fallin   CON      False
# 181011   2018-10-17    OR         2         Mark Roberts   IPO      False
# 45101    2018-09-13    SC         5     Michael Chandler   CON      False
# 219834   2018-08-18    MD         4        Anthony Brown     D       True
# 192686   2018-10-29    CA         9       Jerry McNerney     D       True
# 28289    2018-08-28    MN         2          Angie Craig     D      False
# 24525    2018-08-24    TN         6          Dawn Barlow     D      False
# 228076   2018-08-26    MD         4     George McDermott     R      False
# 282452   2018-10-18    FL        11       Daniel Webster     R       True
# 57321    2018-09-25    NY        18      James O'Donnell     R      False
# 19837    2018-08-20    HI         1               Others   NaN      False
# 165310   2018-10-02    MO         1        Robert Vroman     R      False
# 112554   2018-08-12    IA         1             Rod Blum     R       True
# 83586    2018-10-21    CO         2           Joe Neguse     D      False
# 127783   2018-08-27    CA         2      Dale K. Mensing     R      False
# 192629   2018-10-29    AL         2        Tabitha Isner     D      False
# 87660    2018-10-25    CA        32      Joshua M. Scott     R      False
# 191867   2018-10-28    IA         2   Christopher Peters     R      False
# 166759   2018-10-03    TX        26         Linsey Fagan     D      False
# 15734    2018-08-16    ID         1               Others   NaN      False
# 95564    2018-11-01    SC         3           Mary Geren     D      False
# 137396   2018-09-05    MA         1      Richard E. Neal     D       True
#
#           model  win_probability  voteshare  p10_voteshare  p90_voteshare  \
# 268221     lite           0.0003      25.83          18.87          32.82
# 246253     lite           1.0000      78.40          73.69          83.11
# 206983     lite           0.7861      53.43          47.86          59.10
# 265335     lite           0.0000       2.85           0.83           5.38
# 59872   classic           0.0000      20.69          15.58          25.84
# 197008   deluxe           1.0000      68.66          62.95          74.31
# 105436   deluxe           0.0009      34.45          29.31          39.55
# 274300     lite           1.0000      83.31          76.52          90.11
# 297629     lite           0.5152      50.14          45.50          54.78
# 194609   deluxe           0.0153      41.56          36.81          46.30
# 268783     lite           0.7545      52.29          47.99          56.58
# 206217     lite           0.0391      39.81          32.49          46.97
# 62000   classic           0.0570      43.79          38.79          48.73
# 122936   deluxe           0.0396      42.99          37.94          47.98
# 177581   deluxe           0.0029      37.70          32.63          42.78
# 144920   deluxe           0.0001      32.32          27.11          37.49
# 98562   classic           0.9999      68.62          63.61          73.66
# 238601     lite           1.0000      89.58          83.31          95.12
# 238151     lite           0.9995      70.31          63.40          77.19
# 2867    classic           0.0003      31.35          25.88          36.82
# 51054   classic           0.0254      40.02          34.67          45.34
# 108001   deluxe           1.0000      84.45          76.77          91.46
# 297493     lite           0.0014      29.62          22.50          36.70
# 233618     lite           0.9999      74.80          67.73          81.86
# 248192     lite           0.0552      41.10          34.03          48.06
# 222479     lite           0.4345      47.36          41.25          53.50
# 81268   classic           0.9205      53.61          48.89          58.30
# 113646   deluxe           0.9913      59.75          54.86          64.69
# 81431   classic           0.9668      60.22          53.08          67.29
# 208595     lite           0.0000       3.78           1.16           7.05
# ...         ...              ...        ...            ...            ...
# 70581   classic           0.0000       2.87           0.86           5.37
# 157877   deluxe           0.0082      38.59          33.62          43.48
# 11585   classic           0.9999      67.32          62.25          72.38
# 142921   deluxe           0.0180      41.33          36.28          46.38
# 32718   classic           0.9704      55.97          51.11          60.80
# 189607   deluxe           0.0000      16.67          12.25          21.10
# 250885     lite           0.0467      40.54          33.44          47.61
# 287294     lite           0.9628      55.29          50.39          60.15
# 265285     lite           0.0000       2.91           0.87           5.50
# 181011   deluxe           0.0000       4.29           1.59           7.55
# 45101   classic           0.0001       2.81           0.80           5.36
# 219834     lite           1.0000      79.19          72.43          85.90
# 192686   deluxe           0.9995      64.37          59.72          69.05
# 28289   classic           0.7838      52.73          48.19          57.19
# 24525   classic           0.0000      26.44          20.88          31.95
# 228076     lite           0.0000      17.19          10.49          23.84
# 282452     lite           0.9956      66.42          59.28          73.59
# 57321   classic           0.0113      40.16          35.03          45.37
# 19837   classic           0.0000       4.93           1.75           8.79
# 165310   deluxe           0.0000      19.98          14.87          25.04
# 112554   deluxe           0.1861      44.95          39.60          50.30
# 83586   classic           0.9997      63.02          57.69          68.34
# 127783   deluxe           0.0000      20.12          15.70          24.52
# 192629   deluxe           0.0147      41.16          36.18          46.04
# 87660   classic           0.0000      18.05          13.48          22.57
# 191867   deluxe           0.0052      38.74          34.09          43.32
# 166759   deluxe           0.0005      33.02          27.82          38.13
# 15734   classic           0.0000      12.56           6.79          18.97
# 95564   classic           0.0004      33.25          28.22          38.31
# 137396   deluxe           1.0000     100.00         100.00         100.00
#
#        state_district
# 268221           MA_2
# 246253           CA_6
# 206983           VA_2
# 265335           NJ_7
# 59872           CA_43
# 197008           HI_1
# 105436           KY_4
# 274300           IL_4
# 297629           VA_5
# 194609           VA_1
# 268783           VA_2
# 206217           FL_3
# 62000            FL_7
# 122936           KS_4
# 177581           MA_9
# 144920           OH_6
# 98562            OH_6
# 238601           NY_7
# 238151           FL_5
# 2867             SC_4
# 51054            NJ_2
# 108001           TX_9
# 297493           TN_3
# 233618           SC_6
# 248192           VA_6
# 222479           WI_1
# 81268           TX_31
# 113646           IN_5
# 81431            CA_8
# 208595           MO_5
# ...               ...
# 70581            NC_4
# 157877           IA_2
# 11585           GA_10
# 142921           PA_6
# 32718           PA_16
# 189607          CA_14
# 250885           NE_1
# 287294          TX_31
# 265285           NC_7
# 181011           OR_2
# 45101            SC_5
# 219834           MD_4
# 192686           CA_9
# 28289            MN_2
# 24525            TN_6
# 228076           MD_4
# 282452          FL_11
# 57321           NY_18
# 19837            HI_1
# 165310           MO_1
# 112554           IA_1
# 83586            CO_2
# 127783           CA_2
# 192629           AL_2
# 87660           CA_32
# 191867           IA_2
# 166759          TX_26
# 15734            ID_1
# 95564            SC_3
# 137396           MA_1
#
# [242287 rows x 12 columns]

# %% [markdown]
# We will create two dataframes out of the df which has predictors and labels. As we dont want to apply transformation for target values. And we are dropping all the columns that might be irrelevant as per the correlation matrix too.

# %% [markdown]
# # Predictors and labels

# %%
df_predictors = strat_train_set.drop(["win_probability","forecastdate","special","candidate","incumbent","model","p10_voteshare","p90_voteshare"],axis=1)
df_predictors_labels = strat_train_set["win_probability"].copy()

# %% [markdown]
# to make use of text data we need to convert it into numerical form. Here we will convert state, party into numerical form.

# %%
from sklearn.preprocessing import LabelEncoder
encoder_party = LabelEncoder()
party_cat = df_predictors["party"]
party_cat_encoded = encoder_party.fit_transform(party_cat.astype(str))
party_cat_encoded
# Out:
# array([15,  2, 15, ..., 22,  2,  2])

# %%
print(encoder_party.classes_)
# Out:
# ['AME' 'CON' 'D' 'DPD' 'G' 'GRE' 'I' 'IND' 'IPO' 'Independence Party' 'L'
#  'LIB' 'Legal Marijuana Now' 'Mountain' 'NPA' 'R' 'REF' 'Reform Party'
#  'US Taxpayers' 'WOF' "Women's Equality Party" 'Working Class' 'nan']

# %%
encoder = LabelEncoder()
state_cat = df_predictors["state"]
state_cat_encoded = encoder.fit_transform(state_cat.astype(str))
state_cat_encoded
# Out:
# array([18,  4, 44, ..., 12, 39, 18])

# %%
print(encoder.classes_)
# Out:
# ['AK' 'AL' 'AR' 'AZ' 'CA' 'CO' 'CT' 'DE' 'FL' 'GA' 'HI' 'IA' 'ID' 'IL'
#  'IN' 'KS' 'KY' 'LA' 'MA' 'MD' 'ME' 'MI' 'MN' 'MO' 'MS' 'MT' 'NC' 'ND'
#  'NE' 'NH' 'NJ' 'NM' 'NV' 'NY' 'OH' 'OK' 'OR' 'PA' 'RI' 'SC' 'SD' 'TN'
#  'TX' 'UT' 'VA' 'VT' 'WA' 'WI' 'WV' 'WY']

# %% [markdown]
# We are creating two categories of columns in-order to transform them in data pipeline. We are removing all the non-numerical columns and also the target value column "win_probability". We have only categorial columns that are strings "party" and "state_district"

# %%
cat_attributes = ["party","state_district","state"]

# %% [markdown]
# # Data pipeline
#
# Generally in the pipeline we an use different transformations that ssklearn provides us with but since data seems tobe pretty consistent for this dataset. So we wont be using imputer or standard scaler. But we will be using LabelEncoder for string categorial data. FaetureUnion from scikit learn makes it simple to run multiple tranformation on data parallely.

# %%
from sklearn.pipeline import FeatureUnion,make_pipeline

# %% [markdown]
# Since we have multiple label columns, we might need a multiple column label encoder. sklearn supports multilabelencoder but not multilabelencoder. The solution is influenced by this answer in stackoverflow (https://stackoverflow.com/questions/24458645/label-encoding-across-multiple-columns-in-scikit-learn). Check "data.py" for implementation.

# %%
from data import MultiColumnLabelEncoder
df_predictors_prepared = MultiColumnLabelEncoder(cat_attributes).fit_transform(df_predictors)

# %% [markdown]
# # Lets try out some models
#
# Since we are predicting a target numeric value this falls under regression task. We can use Linear regression, multivariate regression, Decision Trees and Random Forests. Let's try out some.

# %%
from sklearn.linear_model import LinearRegression

# %%
linReg = LinearRegression()
linReg.fit(df_predictors_prepared,df_predictors_labels)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
ex_data = df_predictors.iloc[:8]
ex_label = df_predictors_labels.iloc[:8]
ex_prepared = MultiColumnLabelEncoder(cat_attributes).fit_transform(ex_data)

# %%
print(linReg.predict(ex_prepared))
# Out:
# [ 0.04952466  0.91167928  0.51984593 -0.32850698 -0.08220511  0.75412595
#   0.17924392  1.00101316]

# %%
print(list(ex_label))
# Out:
# [0.0003, 1.0, 0.7861, 0.0, 0.0, 1.0, 0.0009, 1.0]

# %%
from sklearn.metrics import mean_squared_error
df_predictions = linReg.predict(df_predictors_prepared)
linMse = mean_squared_error(df_predictors_labels,df_predictions)
linRmse = np.sqrt(linMse)
linRmse
# Out:
# 0.2159172967381137

# %% [markdown]
# We experimented with Linear regression here. We took a sample data of 8 samples and predicted their target values. And compared them to the actual values. We can see there is lot of descrepency. So lets try Decision trees.

# %%
from sklearn.tree import DecisionTreeRegressor
dtreeReg = DecisionTreeRegressor()
dtreeReg.fit(df_predictors_prepared,df_predictors_labels)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
df_predictions = dtreeReg.predict(df_predictors_prepared)
dtreeMse = mean_squared_error(df_predictors_labels,df_predictions)
dtreeRmse = np.sqrt(dtreeMse)
dtreeRmse
# Out:
# 0.00463934728681046

# %% [markdown]
# That is surprisingly low. But we may have overfit the model. Lets try it with Random forests.

# %%
from sklearn.ensemble import RandomForestRegressor
rfReg = RandomForestRegressor()
rfReg.fit(df_predictors_prepared,df_predictors_labels)
df_predictions = rfReg.predict(df_predictors_prepared)
rfRegMse = mean_squared_error(df_predictors_labels,df_predictions)
rfRegRmse = np.sqrt(rfRegMse)
rfRegRmse
# Out:
# /home/pavani/ml/ml_env/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.005548291077462744

# %% [markdown]
# # Final test
# Now is the time to test it with test data. Lets finalize the model to be Random Forests. Keep in mind this might not be a real life scenario as you may want to tweak a bit till you find the best model.

# %%
X_test = strat_test_set.drop(["win_probability","forecastdate","special","candidate","incumbent","model","p10_voteshare","p90_voteshare"],axis=1)
y_test = strat_test_set["win_probability"].copy()
X_test_prepared = MultiColumnLabelEncoder(cat_attributes).fit_transform(X_test)
final_predictions = rfReg.predict(X_test_prepared)
final_mse = mean_squared_error(y_test,final_predictions)
final_rmse = np.sqrt(final_mse)
final_rmse
# Out:
# 0.00991865304438914
